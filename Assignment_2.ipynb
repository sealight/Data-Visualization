# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import kde
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Dataset 1

# %%
#manually uploaded this csv file
fullpath= '/content/abalone_data.csv'
#read csv into a dataframe
df = pd.read_csv(fullpath, error_bad_lines=False)

# %%
sns.pairplot(df, hue = 'Diameter')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...

# %% [markdown]
# # Dataset 2

# %%
#manually uploaded this csv file
fullpath2= '/content/forestfires.csv'
#read csv into a dataframe
df2 = pd.read_csv(fullpath2, error_bad_lines=False)

# %%
#create andrews curves
x = pd.plotting.andrews_curves(df2, 'day') 
  
#plotting the curve 
x.plot() 
plt.show()

# %% [markdown]
# # Dataset 3

# %%
#manually uploaded this csv file
fullpath3= '/content/wine_data.csv'
#read csv into a dataframe
df3 = pd.read_csv(fullpath3, error_bad_lines=False)

# %%
df3.plot(kind='bar', stacked=True, width=1)
